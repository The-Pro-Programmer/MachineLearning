# %%
#POS: Parts of Speech

import nltk

from nltk.tokenize import word_tokenize
from nltk import pos_tag

def explain_pos_tag(tag):
    tag_meaning = {
        'CC': 'Coordinating conjunction',
        'CD': 'Cardinal number',
        'DT': 'Determiner',
        'EX': 'Existential there',
        'FW': 'Foreign word',
        'IN': 'Preposition or subordinating conjunction',
        'JJ': 'Adjective',
        'JJR': 'Adjective, comparative',
        'JJS': 'Adjective, superlative',
        'LS': 'List item marker',
        'MD': 'Modal',
        'NN': 'Noun, singular or mass',
        'NNS': 'Noun, plural',
        'NNP': 'Proper noun, singular',
        'NNPS': 'Proper noun, plural',
        'PDT': 'Predeterminer',
        'POS': 'Possessive ending',
        'PRP': 'Personal pronoun',
        'PRP$': 'Possessive pronoun',
        'RB': 'Adverb',
        'RBR': 'Adverb, comparative',
        'RBS': 'Adverb, superlative',
        'RP': 'Particle',
        'SYM': 'Symbol',
        'TO': 'to',
        'UH': 'Interjection',
        'VB': 'Verb, base form',
        'VBD': 'Verb, past tense',
        'VBG': 'Verb, gerund or present participle',
        'VBN': 'Verb, past participle',
        'VBP': 'Verb, non-3rd person singular present',
        'VBZ': 'Verb, 3rd person singular present',
        'WDT': 'Wh-determiner',
        'WP': 'Wh-pronoun',
        'WP$': 'Possessive wh-pronoun',
        'WRB': 'Wh-adverb'
    }
    return tag_meaning.get(tag, 'Unknown tag')

def printStats(sentence):
    tokens = word_tokenize(sentence)
    pos_tags = pos_tag(tokens)
    print(f"Text: {sentence}")
    for word, tag in pos_tags:
        print(f"{word}: " + explain_pos_tag(tag))

sentence_english = "Filter out stopwords from text and print the cleaned text."
printStats(sentence_english)
# Out:
# Text: Filter out stopwords from text and print the cleaned text.
# Filter: Noun, singular or mass
# out: Particle
# stopwords: Noun, plural
# from: Preposition or subordinating conjunction
# text: Noun, singular or mass
# and: Coordinating conjunction
# print: Verb, base form
# the: Determiner
# cleaned: Adjective
# text: Noun, singular or mass
# .: Unknown tag

# %%
pip install nltk indic-nlp-library
# Out:
# ...
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.4.1
#     Uninstalling zipp-3.4.1:
#       Successfully uninstalled zipp-3.4.1
#   Attempting uninstall: sphinxcontrib-serializinghtml
#     Found existing installation: sphinxcontrib-serializinghtml 1.1.4
#     Uninstalling sphinxcontrib-serializinghtml-1.1.4:
#       Successfully uninstalled sphinxcontrib-serializinghtml-1.1.4
#   Attempting uninstall: sphinxcontrib-htmlhelp
#     Found existing installation: sphinxcontrib-htmlhelp 1.0.3
#     Uninstalling sphinxcontrib-htmlhelp-1.0.3:
#       Successfully uninstalled sphinxcontrib-htmlhelp-1.0.3
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 4.0.1
#     Uninstalling Sphinx-4.0.1:
#       Successfully uninstalled Sphinx-4.0.1
# ...

# %%
#POS: Parts of Speech

import nltk

from nltk.tokenize import word_tokenize
from nltk import pos_tag
from indicnlp.tokenize import indic_tokenize
from indicnlp import loader
from indicnlp.pos import tagger

text_hindi = "मैं अच्छी तरह से हिंदी नहीं बोलता"
printStats(text_hindi)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-616db04142ae> in <module>
#       7 from indicnlp.tokenize import indic_tokenize
#       8 from indicnlp import loader
# ----> 9 from indicnlp.pos import tagger
#      10
#      11 text_hindi = "मैं अच्छी तरह से हिंदी नहीं बोलता"
#
# ModuleNotFoundError: No module named 'indicnlp.pos'
